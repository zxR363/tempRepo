# %%
import pandas as pd
import numpy as np


df = pd.read_excel("frotokarlilik.xlsx")
df.head()
# Out:
#   web-scraper-order                          web-scraper-start-url     FROTO  \
# 0     1635149547-54  https://www.halkyatirim.com.tr/skorkart/FROTO  Yıllık %
# 1     1635149547-43  https://www.halkyatirim.com.tr/skorkart/FROTO   2019/12
# 2     1635149547-38  https://www.halkyatirim.com.tr/skorkart/FROTO   2021/03
# 3     1635149547-47  https://www.halkyatirim.com.tr/skorkart/FROTO   2018/12
# 4     1635149547-37  https://www.halkyatirim.com.tr/skorkart/FROTO   2021/06
#
#    Brüt Kâr Marjı (%) (Çeyrek)  Brüt Kâr Marjı (%) (Yıllıklandırılmış)  \
# 0                        21.53                                   22.28
# 1                        10.00                                   10.24
# 2                        12.72                                   12.75
# 3                         9.53                                   10.39
# 4                        14.40                                   13.12
#
#    Faaliyet Giderleri Marjı (%) (Çeyrek)  \
# ...

# %%
df = df.sort_values(by="FROTO",ascending=False)
df.head()
# Out:
#    web-scraper-order                          web-scraper-start-url     FROTO  \
# 14     1635149547-53  https://www.halkyatirim.com.tr/skorkart/FROTO  Çeyrek %
# 0      1635149547-54  https://www.halkyatirim.com.tr/skorkart/FROTO  Yıllık %
# 4      1635149547-37  https://www.halkyatirim.com.tr/skorkart/FROTO   2021/06
# 2      1635149547-38  https://www.halkyatirim.com.tr/skorkart/FROTO   2021/03
# 11     1635149547-39  https://www.halkyatirim.com.tr/skorkart/FROTO   2020/12
#
#     Brüt Kâr Marjı (%) (Çeyrek)  Brüt Kâr Marjı (%) (Yıllıklandırılmış)  \
# 14                        13.22                                    2.90
# 0                         21.53                                   22.28
# 4                         14.40                                   13.12
# 2                         12.72                                   12.75
# 11                        13.30                                   12.51
#
#     Faaliyet Giderleri Marjı (%) (Çeyrek)  \
# ...

# %%
df = df.iloc[:, 2:]
df.head()
# Out:
#        FROTO  Brüt Kâr Marjı (%) (Çeyrek)  \
# 14  Çeyrek %                        13.22
# 0   Yıllık %                        21.53
# 4    2021/06                        14.40
# 2    2021/03                        12.72
# 11   2020/12                        13.30
#
#     Brüt Kâr Marjı (%) (Yıllıklandırılmış)  \
# 14                                    2.90
# 0                                    22.28
# 4                                    13.12
# 2                                    12.75
# 11                                   12.51
#
#     Faaliyet Giderleri Marjı (%) (Çeyrek)  \
# 14                                  56.64
# 0                                    2.76
# 4                                    4.90
# 2                                    3.13
# 11                                   3.38
#
#     Faaliyet Giderleri Marjı (%) (Yıllıklandırılmış)  \
# 14                                              3.72
# 0                                              -8.77
# ...

# %%
tmpDf = df.iloc[0:2,:]
df=df.iloc[2:,:]
df = df.append(tmpDf)

# %%
df.tail()
# Out:
#        FROTO  Brüt Kâr Marjı (%) (Çeyrek)  \
# 13   2018/03                        10.40
# 9    2017/12                        10.21
# 10   2017/09                        11.45
# 14  Çeyrek %                        13.22
# 0   Yıllık %                        21.53
#
#     Brüt Kâr Marjı (%) (Yıllıklandırılmış)  \
# 13                                   10.44
# 9                                    10.41
# 10                                   10.68
# 14                                    2.90
# 0                                    22.28
#
#     Faaliyet Giderleri Marjı (%) (Çeyrek)  \
# 13                                   4.01
# 9                                    4.43
# 10                                   4.63
# 14                                  56.64
# 0                                    2.76
#
#     Faaliyet Giderleri Marjı (%) (Yıllıklandırılmış)  \
# 13                                              4.29
# 9                                               4.38
# ...

# %%
df.to_csv('aaa.csv', encoding='iso-8859-9')

# %%
df.head(100)
# Out:
#        FROTO  Brüt Kâr Marjı (%) (Çeyrek)  \
# 4    2021/06                        14.40
# 2    2021/03                        12.72
# 11   2020/12                        13.30
# 8    2020/09                        12.31
# 12   2020/06                        11.85
# 15   2020/03                        11.44
# 1    2019/12                        10.00
# 7    2019/09                        10.22
# 6    2019/06                        10.64
# 16   2019/03                        10.17
# 3    2018/12                         9.53
# 17   2018/09                        10.58
# 5    2018/06                        11.25
# 13   2018/03                        10.40
# 9    2017/12                        10.21
# 10   2017/09                        11.45
# 14  Çeyrek %                        13.22
# 0   Yıllık %                        21.53
#
#     Brüt Kâr Marjı (%) (Yıllıklandırılmış)  \
# 4                                    13.12
# 2                                    12.75
# ...
